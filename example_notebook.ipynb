# %% [markdown]
# # This example shows how you can write code in a notebook and import it into a main.py file or other notebooks.

# %%
class pet:
    def __init__(self):
        print("INIT PET")

# %%
class hello:
    def __init__(self):
        print("INIT HELLO")

# %%
class Bank:
    def __init__(self):
        self.amount = 0

# %%
# 10/0

# %%
def test():
    print("THIS SHOULD BE IMPORTED")
# @i-l
test()
# Out:
# THIS SHOULD BE IMPORTED

# %% [markdown]
# # THIS IS MARKDOWN CELL

# %%
# @i-c
def notImport():
    print("THIS SHOULD NOT BE IMPORTED OR RUN")
notImport()
# Out:
# THIS SHOULD NOT BE IMPORTED OR RUN

# %%
def another():
    print("ANOTHER")
    # @i-l IGNORE LINE below
    # @i-l IGNORE LINE below
    print("LINE SHOULD BE IGNORED")

    # @i-l
    print("Here")

    # @i-l
# @i-l
another()
# Out:
# ANOTHER
# LINE SHOULD BE IGNORED
# Here

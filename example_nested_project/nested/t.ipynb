# %%
import easyjupyter

# %%
from nested.nested_notebook import Bank
# Out:
# ╭───────────────────────── ⚠️ EasyJupyter Syntax Warnings: nested/nested_notebook.ipynb ──────────────────────────╮
# │ • Cell 11 (0-indexed) line 5: Redundant '# @i-l' stacked.                                                       │
# │ • Cell 11 (0-indexed) line 12: Redundant '# @i-l' stacked.                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
# @i-l
# @i-l
print("This line should be ignored")
# Out:
# This line should be ignored

# %%
def t():
    pass
